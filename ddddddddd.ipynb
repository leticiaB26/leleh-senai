# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\leticia_buzo\appdata\roaming\python\python39\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\leticia_buzo\appdata\roaming\python\python39\site-packages (from scikit-learn) (2.0.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\leticia_buzo\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\leticia_buzo\appdata\roaming\python\python39\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\leticia_buzo\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.4.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 24.2 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import pandas as pd

# %%
caminho_arquivo = r'C:\Users\leticia_buzo\Downloads\Frutas.xlsx'
df_frutas=pd.read_excel(caminho_arquivo)

# %%
df_frutas
# Out:
#      Fruta     Cor        Gosto      Formato    Casca
# 0     Limão     Verde      Azedo      Oval       Liso
# 1   Limão     Amarelo    Azedo      Oval       Peludo
# 2     Limão     Verde      Doce       Oval       Liso
# 3     Limão     Amarelo    Azedo      Oval       Liso
# 4   Limão     Verde      Doce       Oval       Peludo
# 5     Banana    Amarelo    Doce       Curvado    Liso
# 6     Banana    Amarelo    Doce       Curvado    Liso
# 7   Banana    Amarelo    Doce       Curvado    Peludo
# 8   Banana    Amarelo    Azedo      Curvado    Peludo
# 9   Banana    Amarelo    Doce       Curvado    Peludo
# 10    Abacaxi   Amarelo    Doce       Alongado   Liso
# 11    Abacaxi   Marrom     Doce       Alongado   Liso
# 12  Abacaxi   Amarelo    Azedo      Alongado   Peludo
# 13  Abacaxi   Amarelo    Azedo      Alongado   Peludo
# 14  Abacaxi   Amarelo    Doce       Alongado   Peludo
# 15    Abacaxi   Amarelo    Doce       Alongado   Liso
# 16  Abacaxi   Amarelo    Doce       Alongado   Peludo
# 17    Abacaxi   Amarelo    Doce       Alongado   Liso
# 18    Abacaxi   Marrom     Doce       Alongado   Liso
# 19    Abacaxi   Amarelo    Doce       Alongado   Liso
# 20    Kiwi      Marrom     Azedo      Oval       Liso
# 21  Kiwi      Verde      Doce       Oval       Peludo
# 22    Kiwi      Marrom     Doce       Oval       Liso
# 23    Kiwi      Verde      Azedo      Oval       Liso
# 24    Kiwi      Marrom     Doce       Oval       Liso
# 25    Kiwi      Marrom     Azedo      Oval       Liso
# 26  Kiwi      Marrom     Doce       Oval       Peludo
# 27  Kiwi      Marrom     Azedo      Oval       Peludo
# 28    Kiwi      Verde      Azedo      Oval       Liso
# 29  Kiwi      Verde      Doce       Oval       Peludo
# 30  Kiwi      Verde      Azedo      Oval       Peludo
# 31    Kiwi      Marrom     Azedo      Oval       Liso
# 32  Kiwi      Verde      Azedo      Oval       Peludo
# 33    Kiwi      Marrom     Azedo      Oval       Liso
# 34    Kiwi      Marrom     Azedo      Oval       Liso

# %%
df_frutas=df_frutas['Fruta     Cor        Gosto      Formato    Casca'].str.split(expand=True)

df_frutas.columns=['Frutas','Cor','Sabor','Formato','Textura']

# %%
df_frutas
# Out:
#      Frutas      Cor  Sabor   Formato Textura
# 0     Limão    Verde  Azedo      Oval    Liso
# 1     Limão  Amarelo  Azedo      Oval  Peludo
# 2     Limão    Verde   Doce      Oval    Liso
# 3     Limão  Amarelo  Azedo      Oval    Liso
# 4     Limão    Verde   Doce      Oval  Peludo
# 5    Banana  Amarelo   Doce   Curvado    Liso
# 31   Marrom  Azedo      Oval    Liso
# 32    Verde  Azedo      Oval  Peludo
# 33   Marrom  Azedo      Oval    Liso
# 34   Marrom  Azedo      Oval    Liso

# %%
mapeamento_cor={'Verde':0,'Amarelo':1,'Marrom':2}
mapeamento_sabor={'Azedo':0,'Doce':1}
mapeamento_formato={'Oval':0,'Curvado':1,'Alongado':2}
mapeamento_textura={'Liso':0,'Peludo':1}

# %%
x=df_frutas[['Cor','Sabor','Formato','Textura']]
x['Cor']=x['Cor'].map(mapeamento_cor)
x['Sabor']=x['Sabor'].map(mapeamento_sabor)
x['Formato']=x['Formato'].map(mapeamento_formato)
x['Textura']=x['Textura'].map(mapeamento_textura)
# Out:
# C:\Users\leticia_buzo\AppData\Local\Temp\ipykernel_14396\1855933408.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Cor']=x['Cor'].map(mapeamento_cor)
# C:\Users\leticia_buzo\AppData\Local\Temp\ipykernel_14396\1855933408.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Sabor']=x['Sabor'].map(mapeamento_sabor)
# C:\Users\leticia_buzo\AppData\Local\Temp\ipykernel_14396\1855933408.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Formato']=x['Formato'].map(mapeamento_formato)
# C:\Users\leticia_buzo\AppData\Local\Temp\ipykernel_14396\1855933408.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Textura']=x['Textura'].map(mapeamento_textura)

# %%
x
# Out:
#     Cor  Sabor  Formato  Textura
# 0     0      0        0        0
# 1     1      0        0        1
# 2     0      1        0        0
# 3     1      0        0        0
# 4     0      1        0        1
# 5     1      1        1        0
# 6     1      1        1        0
# 7     1      1        1        1
# 8     1      0        1        1
# 9     1      1        1        1
# 10    1      1        2        0
# 11    2      1        2        0
# 12    1      0        2        1
# 13    1      0        2        1
# 14    1      1        2        1
# 15    1      1        2        0
# 16    1      1        2        1
# 17    1      1        2        0
# 18    2      1        2        0
# 19    1      1        2        0
# 20    2      0        0        0
# 21    0      1        0        1
# 22    2      1        0        0
# 23    0      0        0        0
# 24    2      1        0        0
# 25    2      0        0        0
# 26    2      1        0        1
# 27    2      0        0        1
# 28    0      0        0        0
# 29    0      1        0        1
# 30    0      0        0        1
# 31    2      0        0        0
# 32    0      0        0        1
# 33    2      0        0        0
# 34    2      0        0        0

# %%
df_frutas
# Out:
#      Frutas      Cor  Sabor   Formato Textura
# 0     Limão    Verde  Azedo      Oval    Liso
# 1     Limão  Amarelo  Azedo      Oval  Peludo
# 2     Limão    Verde   Doce      Oval    Liso
# 3     Limão  Amarelo  Azedo      Oval    Liso
# 4     Limão    Verde   Doce      Oval  Peludo
# 5    Banana  Amarelo   Doce   Curvado    Liso
# 6    Banana  Amarelo   Doce   Curvado    Liso
# 7    Banana  Amarelo   Doce   Curvado  Peludo
# 8    Banana  Amarelo  Azedo   Curvado  Peludo
# 9    Banana  Amarelo   Doce   Curvado  Peludo
# 10  Abacaxi  Amarelo   Doce  Alongado    Liso
# 11  Abacaxi   Marrom   Doce  Alongado    Liso
# 12  Abacaxi  Amarelo  Azedo  Alongado  Peludo
# 13  Abacaxi  Amarelo  Azedo  Alongado  Peludo
# 14  Abacaxi  Amarelo   Doce  Alongado  Peludo
# 15  Abacaxi  Amarelo   Doce  Alongado    Liso
# 16  Abacaxi  Amarelo   Doce  Alongado  Peludo
# 17  Abacaxi  Amarelo   Doce  Alongado    Liso
# 18  Abacaxi   Marrom   Doce  Alongado    Liso
# 19  Abacaxi  Amarelo   Doce  Alongado    Liso
# 20     Kiwi   Marrom  Azedo      Oval    Liso
# 21     Kiwi    Verde   Doce      Oval  Peludo
# 22     Kiwi   Marrom   Doce      Oval    Liso
# 23     Kiwi    Verde  Azedo      Oval    Liso
# 24     Kiwi   Marrom   Doce      Oval    Liso
# 25     Kiwi   Marrom  Azedo      Oval    Liso
# 26     Kiwi   Marrom   Doce      Oval  Peludo
# 27     Kiwi   Marrom  Azedo      Oval  Peludo
# 28     Kiwi    Verde  Azedo      Oval    Liso
# 29     Kiwi    Verde   Doce      Oval  Peludo
# 30     Kiwi    Verde  Azedo      Oval  Peludo
# 31     Kiwi   Marrom  Azedo      Oval    Liso
# 32     Kiwi    Verde  Azedo      Oval  Peludo
# 33     Kiwi   Marrom  Azedo      Oval    Liso
# 34     Kiwi   Marrom  Azedo      Oval    Liso

# %%
X_train,X_test,Y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=37)

modelo=DecisionTreeClassifier()
modelo.fit(X_train,Y_train)
previsoes=modelo.predict(X_test)

# %%
caminho_arquivo2 = r'C:\Users\leticia_buzo\Downloads\Frutas2.xlsx'
df_frutas2=pd.read_excel(caminho_arquivo2)

# %%
df_frutas2['Cor']=df_frutas2['Cor'].map(mapeamento_cor)
df_frutas2['Sabor']=df_frutas2['Sabor'].map(mapeamento_sabor)
df_frutas2['Formato']=df_frutas2['Formato'].map(mapeamento_formato)
df_frutas2['Textura']=df_frutas2['Textura'].map(mapeamento_textura)
previsoes_novo_dados=modelo.predict(df_frutas2)
previsoes_novo_dados
# Out:
# array(['Banana', 'Kiwi', 'Banana', 'Kiwi'], dtype=object)

# %%
df_frutas2
# Out:
#    Cor  Sabor  Formato  Textura
# 0    1      1        1        0
# 1    2      0        0        1
# 2    1      1        1        0
# 3    0      0        0        0

# %%
caminho_arquivo3 = r'C:\Users\leticia_buzo\Downloads\cliente_compras.xlsx'
df_cliente=pd.read_excel(caminho_arquivo3)

# %%
df_cliente
# Out:
#     tempo_gasto_site  numero_itens_visualizados compras_anteriores compra
# 0                 10                          5                Não    Não
# 1                 15                          7                Sim    Sim
# 2                 20                          8                Sim    Sim
# 3                  5                          3                Não    Não
# 4                 25                         10                Sim    Sim
# 5                 30                         12                Sim    Sim
# 6                  8                          4                Não    Não
# 7                 12                          6                Sim    Sim
# 8                 18                          9                Sim    Sim
# 9                  7                          3                Não    Não
# 10                22                         11                Sim    Sim
# 11                28                         13                Sim    Sim
# 12                 6                          2                Não    Não
# 13                14                          7                Sim    Sim
# 14                16                          8                Sim    Sim
# 15                 9                          4                Não    Não
# 16                24                         10                Sim    Sim
# 17                32                         14                Sim    Sim
# 18                11                          5                Não    Não
# 19                21                          9                Sim    Sim
# 20                26                         11                Sim    Sim
# 21                13                          6                Sim    Sim
# 22                19                          8                Sim    Sim
# 23                17                          7                Sim    Sim
# 24                23                         10                Sim    Sim
# 25                27                         12                Sim    Sim
# 26                29                         13                Sim    Sim
# 27                31                         14                Sim    Sim
# 28                33                         15                Sim    Sim
# 29                35                         16                Sim    Sim
# 30                37                         17                Sim    Sim
# 31                39                         18                Sim    Sim
# 32                41                         19                Sim    Sim
# 33                43                         20                Sim    Sim
# 34                45                         21                Sim    Sim
# 35                47                         22                Sim    Sim
# 36                49                         23                Sim    Sim
# 37                51                         24                Sim    Sim
# 38                53                         25                Sim    Sim
# 39                55                         26                Sim    Sim
# 40                57                         27                Sim    Sim
# 41                59                         28                Sim    Sim
# 42                61                         29                Sim    Sim
# 43                63                         30                Sim    Sim
# 44                65                         31                Sim    Sim
# 45                67                         32                Sim    Sim
# 46                69                         33                Sim    Sim
# 47                71                         34                Sim    Sim

# %%
df_cliente=df_cliente['compras_anteriores'].str.split(expand=True)

# %%
df_cliente
# Out:
#       0
# 0   Não
# 1   Sim
# 2   Sim
# 3   Não
# 4   Sim
# 5   Sim
# 6   Não
# 7   Sim
# 8   Sim
# 9   Não
# 10  Sim
# 11  Sim
# 12  Não
# 13  Sim
# 14  Sim
# 15  Não
# 16  Sim
# 17  Sim
# 18  Não
# 19  Sim
# 20  Sim
# 21  Sim
# 22  Sim
# 23  Sim
# 24  Sim
# 25  Sim
# 26  Sim
# 27  Sim
# 28  Sim
# 29  Sim
# 30  Sim
# 31  Sim
# 32  Sim
# 33  Sim
# 34  Sim
# 35  Sim
# 36  Sim
# 37  Sim
# 38  Sim
# 39  Sim
# 40  Sim
# 41  Sim
# 42  Sim
# 43  Sim
# 44  Sim
# 45  Sim
# 46  Sim
# 47  Sim

# %%
df_cliente.columns=['tempo_gasto_site','numero_itens_visualizados','compras_anteriores']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df_cliente.columns=['tempo_gasto_site','numero_itens_visualizados','compras_anteriores']
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=6310'>6311</a> try:
#    <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=6311'>6312</a>     object.__getattribute__(self, name)
# -> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=6312'>6313</a>     return object.__setattr__(self, name, value)
#    <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=6313'>6314</a> except AttributeError:
#    <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=6314'>6315</a>     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=808'>809</a> """
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=809'>810</a> This is called from the cython code when we set the `index` attribute
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=810'>811</a> directly, e.g. `series.index = [1, 2, 3]`.
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=811'>812</a> """
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=812'>813</a> labels = ensure_index(labels)
# --> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=813'>814</a> self._mgr.set_axis(axis, labels)
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=814'>815</a> self._clear_item_cache()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/internals/managers.py?line=235'>236</a> def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/internals/managers.py?line=236'>237</a>     # Caller is responsible for ensuring we have an Index object.
# --> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/internals/managers.py?line=237'>238</a>     self._validate_set_axis(axis, new_labels)
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/internals/managers.py?line=238'>239</a>     self.axes[axis] = new_labels
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/internals/base.py?line=94'>95</a>     pass
#      <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/internals/base.py?line=96'>97</a> elif new_len != old_len:
# ---> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/internals/base.py?line=97'>98</a>     raise ValueError(
#      <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/internals/base.py?line=98'>99</a>         f"Length mismatch: Expected axis has {old_len} elements, new "
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/internals/base.py?line=99'>100</a>         f"values have {new_len} elements"
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/internals/base.py?line=100'>101</a>     )
#
# ValueError: Length mismatch: Expected axis has 1 elements, new values have 3 elements
